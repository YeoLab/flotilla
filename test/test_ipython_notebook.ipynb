# %%
import flotilla
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
sns.set_context('talk')

# %%
study = flotilla.embark('http://sauron.ucsd.edu/flotilla_projects/neural_diff_chr22/datapackage.json')
# Out:
# initializing study
# predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# added ExtraTreesClassifier to default predictors
# predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# added ExtraTreesRegressor to default predictors
# predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# added GradientBoostingClassifier to default predictors
# predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# added GradientBoostingRegressor to default predictors
# loading expression data
# initializing expression
# done initializing expression
# loading splicing data
# ...

# %%
study.interactive_pca(sample_subsets=['all_samples'], feature_subsets=['protein_coding'], savefile='figure1_a.pdf')
# Out:
# savefile : figure1_a.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : False
# sample_subset : all_samples
# feature_subset : protein_coding
# x_pc : 1
# list_link :

# %%
study.interactive_pca(sample_subsets=['all_samples'], feature_subsets=['protein_coding'], savefile='figure1_b.pdf', featurewise=True)
# Out:
# savefile : figure1_b.pdf
# y_pc : 2
# data_type : expression
# featurewise : True
# show_point_labels : False
# sample_subset : all_samples
# feature_subset : protein_coding
# x_pc : 1
# list_link :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/ipython_interact.pyc in do_interact(data_type, sample_subset, feature_subset, featurewise, list_link, x_pc, y_pc, show_point_labels, savefile)
#     116                                 x_pc=x_pc, y_pc=y_pc,
#     117                                 show_point_labels=show_point_labels,
# --> 118                                 feature_subset=feature_subset)
#     119             if savefile != '':
#     120                 # Make the directory if it's not already there
#
# ...

# %%
study.interactive_graph(feature_subsets=['protein_coding'], savefile='figure2_a.pdf')
# Out:
# savefile : figure2_a.pdf
# data_type : expression
# featurewise : False
# weight_fun : no_weight
# use_pc_4 : True
# use_pc_2 : True
# use_pc_3 : True
# sample_subset : all_samples
# use_pc_1 : True
# cov_std_cut : 1.8
# feature_subset : protein_coding
# degree_cut : 1
# feature_of_interest : RBFOX2
# draw_labels : False
# n_pcs : 5
# u'RBFOX2'

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
study.interactive_classifier(feature_subsets=['protein_coding'], savefile='figure2_a.pdf')
# Out:
# savefile : figure2_a.pdf
# predictor_type : ExtraTreesClassifier
# data_type : expression
# score_coefficient : 2.0
# sample_subset : all_samples
# feature_subset : protein_coding
# categorical_variable : is_craig
# Fitting a predictor for X:all_samples_protein_coding, y:is_craig, method:ExtraTreesClassifier... please wait.
# configuring predictor type: ExtraTreesClassifier with 450 features[Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# 	Finished.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/ipython_interact.pyc in do_interact(data_type, sample_subset, feature_subset, predictor_type, categorical_variable, score_coefficient, savefile)
#     262                                  predictor_name=predictor_type,
# ...
