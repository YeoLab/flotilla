# %%
# %matplotlib inline #show matplotlib plots inline with code

# %% [markdown]
# #FLOTILLA INTRODUCTION

# %% [markdown]
# Flotilla is a container for software to do genomics things. It is sub-divided into thematic parts that are named after boats.
#
# "object-oriented magic" - schooner
# <img src="img/schooner.png" height=200 width=200/>
#
# "exploratory data viz" - submarine
# <img src="img/submarine.png" height=200 width=200/>
#
# "things for computation" - frigate
# <img src="img/frigate.png" height=200 width=200/>
#
# "draw data from external sources" - skiff
# <img src="img/skiff.png" height=200 width=200/>
#
# "slow-loading things" - cargo
# <img src="img/cargo.png" height=200 width=200/>
#
# "database things" - carrier
# <img src="img/carrier.png" height=200 width=200/>

# %% [markdown]
# projects are stored in separate git repos, access them by import.
#
# <p>neural_diff_project is yan's data, but projects can come with readme's<br> that make the stderr show messages about the data (like below)</p>

# %% [markdown]
# ###users import prjoects using:
#
#  <pre><code>import projectname</code></pre>
#
#  where someone has already installed projectname into the python path.
#
#  This tutorial uses neural_diff_project as an example.

# %%
import pandas as pd

# %%
import neural_diff_project
# Out:
# single cell RNAseq data from IPS (P) NPC (N) Motor Neurons (M) and stressed motor neurons (S), mostly from craig venter,
# npcs not labelled with "CVN" are not craig venter, all others are CVN genotype.
#
# sample ids have a single letter indicating their cell type added from input data
#
# descriptors.df
# rows: cells
# columns: cell metadata
#
# miso_to_ids.df
# rows: events
# columns: event metadata (gene name etc)
#
# psi.df.gz:
# rows: cells
# columns: events
#
# - AFE, ALE, A5SS, A3SS, SE, MXE, TandemUTR events from MISO
# - Filtered on:
#   - Maximum half-size of confidence interval <= 0.2
#   - At least 10 reads that are unique to either isoform
#
# tpm.df.gz:
# rows: cells
# columns: genes
#
# - Transcripts per million (TPM) calculated via Sailfish (k = 31)
# - Transcripts calculated:
#   - gencode v19 protein-coding genes
#   - gencode v19 lncRNAs (long noncoding RNAs)
#   - ERCC spike-ins (named: ERCC-00*)
#   - Fluidigm Spike-ins (named: RNA_Spike_1, RNA_Spike_4, RNA_Spike_7)

# %% [markdown]
# STDERR provides messages about the methods used to make the data.

# %% [markdown]
# ##<b>schooner</b> is an object-oriented user interface.<br>
# <b>schooner.Study</b> takes care of organizing data from multiple sources. It inherits subclasses that have tools to interact with data via IPython widgets, which is really nice.<br>
# <b>schooner.ExpressionData</b> and <b>schooner.SplicingData</b> do classifcation/regression and dimensionality reduction.<br>
# All data types should be available for user interaction (and are expected to be used) via the
# <b>schooner.Study</b> object.
# <br>
# <br>
# ##<b>submarine</b> is a visualization module that entirely depends on the other modules,this is mostly subclasses of the modules in frigate<br>
# ##<b>frigate</b> is the computational workhorse, it holds the objects that do the maths.

# %%
sc_study = neural_diff_project.embark(load_cargo=True, drop_outliers=True)
# Out:
# getting flotilla data from /Users/lovci/Projects/flotilla/flotilla/src/_cargo_commonObjects/cargo_data
# dropping
# importing GO...done.
#  set(['M_M2_07', 'M_M1_03', 'M_M2_05', 'M_M2_02', 'M_M2_01', 'P_P2_06', 'M_M2nd_21', 'S_MSA_21', 'S_MSA_05', 'S_MSA_28', 'M_M2_06', 'M_M3_11', 'M_M6_2', 'M_M6_1', 'M_M2nd_13', 'S_MSA_23', 'M_M3_3', 'M_M1_04', 'M_M3_1', 'M_M4_1', 'M_M4_2', 'M_M4_13', 'M_M4_10'])
# dropping
#  set(['M_M2_07', 'M_M1_03', 'M_M2_05', 'M_M2_02', 'M_M2_01', 'P_P2_06', 'M_M2nd_21', 'M_M2nd_23', 'S_MSA_21', 'S_MSA_05', 'S_MSA_28', 'S_MSA_29', 'M_M2_06', 'M_M3_11', 'M_M6_2', 'M_M6_1', 'M_M2nd_13', 'S_MSA_19', 'S_MSA_23', 'M_M3_3', 'M_M1_04', 'M_M3_1', 'M_M4_2', 'M_M4_13', 'M_M4_10'])

# %% [markdown]
# ###what just happened?
# this puts the expression and splicing data, along with metadata about the <br> samples into an object-oriented interface called flotilla.schooner.Study which is now accessible through the <code>sc_study</code> variable<br>
# load_cargo=True takes >40 seconds to load the first time, it loads GO references into memory and sets up gene names for plots and such <br>

# %% [markdown]
# #Sample Metadata
#
# plotting requires that two columns appear in the sample metadata data frame: "color" and "cell_marker"<br>

# %%
sc_study.sample_info
# Out:
#           R1_fastq.gz_md5sum R2_fastq.gz_md5sum  \
# id
# M_M1_01
# M_M1_02
# M_M1_03
# M_M1_04
# M_M1_05
# M_M1_06
# M_M1_07
# M_M1_08
# M_M1_09
# M_M1_10
# M_M1_11
# M_M1_12
# M_M2_01
# M_M2_02
# M_M2_03
# M_M2_04
# M_M2_05
# M_M2_06
# M_M2_07
# M_M2_08
# M_M2_09
# M_M2_10
# M_M2_11
# M_M2_12
# M_M2nd_01
# M_M2nd_02
# M_M2nd_03
# M_M2nd_04
# M_M2nd_05
# M_M2nd_06
# M_M2nd_07
# M_M2nd_08
# M_M2nd_09
# M_M2nd_10
# M_M2nd_11
# M_M2nd_12
# M_M2nd_13
# M_M2nd_14
# M_M2nd_15
# M_M2nd_16
# M_M2nd_17
# M_M2nd_18
# M_M2nd_19
# M_M2nd_20
# M_M2nd_21
# M_M2nd_22
# M_M2nd_23
# M_M2nd_24
# M_M2nd_25
# M_M2nd_26
# M_M2nd_27
# M_M2nd_28
# M_M2nd_29
# M_M2nd_30
# M_M2nd_31
# M_M2nd_32
# P_M2nd_33
# P_M2nd_34
# M_M3_1
# M_M3_10
#                          ...                ...
#
#                                                 bam_location    batch  \
# id
# M_M1_01    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_02    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_03    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_04    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_05    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_06    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_07    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_08    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_09    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_10    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_11    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M1_12    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_01    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_02    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_03    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_04    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_05    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_06    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_07    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_08    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_09    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_10    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_11    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2_12    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_1
# M_M2nd_01  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_02  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_03  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_04  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_05  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_06  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_07  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_08  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_09  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_10  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_11  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_12  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_13  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_14  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_15  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_16  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_17  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_18  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_19  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_20  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_21  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_22  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_23  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_24  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_25  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_26  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_27  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_28  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_29  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_30  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_31  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M2nd_32  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# P_M2nd_33  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# P_M2nd_34  /oasis/tscc/scratch/ppliu/single_cell_stressed...  round_4
# M_M3_1     /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_2
# M_M3_10    /oasis/tscc/scratch/ppliu/single_cell/single_c...  round_2
#                                                          ...      ...
#
#           cell_type is_craig?  is_pooled is_split_of  outlier M_cell  \
# id
# M_M1_01           M      TRUE          0         NaN        0   True
# M_M1_02           M      TRUE          0         NaN        0   True
# M_M1_03           M      TRUE          0         NaN        1   True
# M_M1_04           M      TRUE          0         NaN        1   True
# M_M1_05           M      TRUE          0         NaN        0   True
# M_M1_06           M      TRUE          0         NaN        0   True
# M_M1_07           M      TRUE          0         NaN        0   True
# M_M1_08           M      TRUE          0         NaN        0   True
# M_M1_09           M      TRUE          0         NaN        0   True
# M_M1_10           M      TRUE          0         NaN        0   True
# M_M1_11           M      TRUE          0         NaN        0   True
# M_M1_12           M      TRUE          0         NaN        0   True
# M_M2_01           M      TRUE          0         NaN        1   True
# M_M2_02           M      TRUE          0         NaN        1   True
# M_M2_03           M      TRUE          0         NaN        0   True
# M_M2_04           M      TRUE          0         NaN        0   True
# M_M2_05           M      TRUE          1         NaN        1   True
# M_M2_06           M      TRUE          0         NaN        1   True
# M_M2_07           M      TRUE          0         NaN        1   True
# M_M2_08           M      TRUE          0         NaN        0   True
# M_M2_09           M      TRUE          0         NaN        0   True
# M_M2_10           M      TRUE          0         NaN        0   True
# M_M2_11           M      TRUE          0         NaN        0   True
# M_M2_12           M      TRUE          0         NaN        0   True
# M_M2nd_01         M      TRUE          0         NaN        0   True
# M_M2nd_02         M      TRUE          0         NaN        0   True
# M_M2nd_03         M      TRUE          0         NaN        0   True
# M_M2nd_04         M      TRUE          0         NaN        0   True
# M_M2nd_05         M      TRUE          0         NaN        0   True
# M_M2nd_06         M      TRUE          0         NaN        0   True
# M_M2nd_07         M      TRUE          0         NaN        0   True
# M_M2nd_08         M      TRUE          0         NaN        0   True
# M_M2nd_09         M      TRUE          0         NaN        0   True
# M_M2nd_10         M      TRUE          0         NaN        0   True
# M_M2nd_11         M      TRUE          0         NaN        0   True
# M_M2nd_12         M      TRUE          0         NaN        0   True
# M_M2nd_13         M      TRUE          1         NaN        1   True
# M_M2nd_14         M      TRUE          0         NaN        0   True
# M_M2nd_15         M      TRUE          0         NaN        0   True
# M_M2nd_16         M      TRUE          0         NaN        0   True
# M_M2nd_17         M      TRUE          0         NaN        0   True
# M_M2nd_18         M      TRUE          0         NaN        0   True
# M_M2nd_19         M      TRUE          0         NaN        0   True
# M_M2nd_20         M      TRUE          0         NaN        0   True
# M_M2nd_21         M      TRUE          1         NaN        1   True
# M_M2nd_22         M      TRUE          0         NaN        0   True
# M_M2nd_23         M      TRUE          0         NaN        1   True
# M_M2nd_24         M      TRUE          0         NaN        0   True
# M_M2nd_25         M      TRUE          0         NaN        0   True
# M_M2nd_26         M      TRUE          0         NaN        0   True
# M_M2nd_27         M      TRUE          0         NaN        0   True
# M_M2nd_28         M      TRUE          0         NaN        0   True
# M_M2nd_29         M      TRUE          0         NaN        0   True
# M_M2nd_30         M      TRUE          0         NaN        0   True
# M_M2nd_31         M      TRUE          0         NaN        0   True
# M_M2nd_32         M      TRUE          0         NaN        0   True
# P_M2nd_33         P      TRUE          1         NaN        0  False
# P_M2nd_34         P      TRUE          1         NaN        0  False
# M_M3_1            M      TRUE          0         NaN        1   True
# M_M3_10           M      TRUE          0         NaN        0   True
#                 ...       ...        ...         ...      ...    ...
#
#           neuron_cell N_cell P_cell S_cell cell_color cell_marker  \
# id
# M_M1_01          True  False  False  False    #e41a1c           D
# M_M1_02          True  False  False  False    #e41a1c           D
# M_M1_03          True  False  False  False    #e41a1c           D
# M_M1_04          True  False  False  False    #e41a1c           D
# M_M1_05          True  False  False  False    #e41a1c           D
# M_M1_06          True  False  False  False    #e41a1c           D
# M_M1_07          True  False  False  False    #e41a1c           D
# M_M1_08          True  False  False  False    #e41a1c           D
# M_M1_09          True  False  False  False    #e41a1c           D
# M_M1_10          True  False  False  False    #e41a1c           D
# M_M1_11          True  False  False  False    #e41a1c           D
# M_M1_12          True  False  False  False    #e41a1c           D
# M_M2_01          True  False  False  False    #e41a1c           D
# M_M2_02          True  False  False  False    #e41a1c           D
# M_M2_03          True  False  False  False    #e41a1c           D
# M_M2_04          True  False  False  False    #e41a1c           D
# M_M2_05          True  False  False  False    #e41a1c           D
# M_M2_06          True  False  False  False    #e41a1c           D
# M_M2_07          True  False  False  False    #e41a1c           D
# M_M2_08          True  False  False  False    #e41a1c           D
# M_M2_09          True  False  False  False    #e41a1c           D
# M_M2_10          True  False  False  False    #e41a1c           D
# M_M2_11          True  False  False  False    #e41a1c           D
# M_M2_12          True  False  False  False    #e41a1c           D
# M_M2nd_01        True  False  False  False    #e41a1c           D
# M_M2nd_02        True  False  False  False    #e41a1c           D
# M_M2nd_03        True  False  False  False    #e41a1c           D
# M_M2nd_04        True  False  False  False    #e41a1c           D
# M_M2nd_05        True  False  False  False    #e41a1c           D
# M_M2nd_06        True  False  False  False    #e41a1c           D
# M_M2nd_07        True  False  False  False    #e41a1c           D
# M_M2nd_08        True  False  False  False    #e41a1c           D
# M_M2nd_09        True  False  False  False    #e41a1c           D
# M_M2nd_10        True  False  False  False    #e41a1c           D
# M_M2nd_11        True  False  False  False    #e41a1c           D
# M_M2nd_12        True  False  False  False    #e41a1c           D
# M_M2nd_13        True  False  False  False    #e41a1c           D
# M_M2nd_14        True  False  False  False    #e41a1c           D
# M_M2nd_15        True  False  False  False    #e41a1c           D
# M_M2nd_16        True  False  False  False    #e41a1c           D
# M_M2nd_17        True  False  False  False    #e41a1c           D
# M_M2nd_18        True  False  False  False    #e41a1c           D
# M_M2nd_19        True  False  False  False    #e41a1c           D
# M_M2nd_20        True  False  False  False    #e41a1c           D
# M_M2nd_21        True  False  False  False    #e41a1c           D
# M_M2nd_22        True  False  False  False    #e41a1c           D
# M_M2nd_23        True  False  False  False    #e41a1c           D
# M_M2nd_24        True  False  False  False    #e41a1c           D
# M_M2nd_25        True  False  False  False    #e41a1c           D
# M_M2nd_26        True  False  False  False    #e41a1c           D
# M_M2nd_27        True  False  False  False    #e41a1c           D
# M_M2nd_28        True  False  False  False    #e41a1c           D
# M_M2nd_29        True  False  False  False    #e41a1c           D
# M_M2nd_30        True  False  False  False    #e41a1c           D
# M_M2nd_31        True  False  False  False    #e41a1c           D
# M_M2nd_32        True  False  False  False    #e41a1c           D
# P_M2nd_33       False  False   True  False    #377eb8           o
# P_M2nd_34       False  False   True  False    #377eb8           o
# M_M3_1           True  False  False  False    #e41a1c           D
# M_M3_10          True  False  False  False    #e41a1c           D
#                   ...    ...    ...    ...        ...         ...
#
#           original_name any_cell    color marker
# id
# M_M1_01           M1_01     True  #e41a1c      D
# M_M1_02           M1_02     True  #e41a1c      D
# M_M1_03           M1_03     True  #e41a1c      D
# M_M1_04           M1_04     True  #e41a1c      D
# M_M1_05           M1_05     True  #e41a1c      D
# M_M1_06           M1_06     True  #e41a1c      D
# M_M1_07           M1_07     True  #e41a1c      D
# M_M1_08           M1_08     True  #e41a1c      D
# M_M1_09           M1_09     True  #e41a1c      D
# M_M1_10           M1_10     True  #e41a1c      D
# M_M1_11           M1_11     True  #e41a1c      D
# M_M1_12           M1_12     True  #e41a1c      D
# M_M2_01           M2_01     True  #e41a1c      D
# M_M2_02           M2_02     True  #e41a1c      D
# M_M2_03           M2_03     True  #e41a1c      D
# M_M2_04           M2_04     True  #e41a1c      D
# M_M2_05           M2_05     True  #e41a1c      D
# M_M2_06           M2_06     True  #e41a1c      D
# M_M2_07           M2_07     True  #e41a1c      D
# M_M2_08           M2_08     True  #e41a1c      D
# M_M2_09           M2_09     True  #e41a1c      D
# M_M2_10           M2_10     True  #e41a1c      D
# M_M2_11           M2_11     True  #e41a1c      D
# M_M2_12           M2_12     True  #e41a1c      D
# M_M2nd_01       M2nd_01     True  #e41a1c      D
# M_M2nd_02       M2nd_02     True  #e41a1c      D
# M_M2nd_03       M2nd_03     True  #e41a1c      D
# M_M2nd_04       M2nd_04     True  #e41a1c      D
# M_M2nd_05       M2nd_05     True  #e41a1c      D
# M_M2nd_06       M2nd_06     True  #e41a1c      D
# M_M2nd_07       M2nd_07     True  #e41a1c      D
# M_M2nd_08       M2nd_08     True  #e41a1c      D
# M_M2nd_09       M2nd_09     True  #e41a1c      D
# M_M2nd_10       M2nd_10     True  #e41a1c      D
# M_M2nd_11       M2nd_11     True  #e41a1c      D
# M_M2nd_12       M2nd_12     True  #e41a1c      D
# M_M2nd_13       M2nd_13     True  #e41a1c      D
# M_M2nd_14       M2nd_14     True  #e41a1c      D
# M_M2nd_15       M2nd_15     True  #e41a1c      D
# M_M2nd_16       M2nd_16     True  #e41a1c      D
# M_M2nd_17       M2nd_17     True  #e41a1c      D
# M_M2nd_18       M2nd_18     True  #e41a1c      D
# M_M2nd_19       M2nd_19     True  #e41a1c      D
# M_M2nd_20       M2nd_20     True  #e41a1c      D
# M_M2nd_21       M2nd_21     True  #e41a1c      D
# M_M2nd_22       M2nd_22     True  #e41a1c      D
# M_M2nd_23       M2nd_23     True  #e41a1c      D
# M_M2nd_24       M2nd_24     True  #e41a1c      D
# M_M2nd_25       M2nd_25     True  #e41a1c      D
# M_M2nd_26       M2nd_26     True  #e41a1c      D
# M_M2nd_27       M2nd_27     True  #e41a1c      D
# M_M2nd_28       M2nd_28     True  #e41a1c      D
# M_M2nd_29       M2nd_29     True  #e41a1c      D
# M_M2nd_30       M2nd_30     True  #e41a1c      D
# M_M2nd_31       M2nd_31     True  #e41a1c      D
# M_M2nd_32       M2nd_32     True  #e41a1c      D
# P_M2nd_33       M2nd_33     True  #377eb8      o
# P_M2nd_34       M2nd_34     True  #377eb8      o
# M_M3_1             M3_1     True  #e41a1c      D
# M_M3_10           M3_10     True  #e41a1c      D
#                     ...      ...      ...    ...
#
# [295 rows x 20 columns]

# %% [markdown]
# #Raw data for gene expression, TPM:

# %%
sc_study.expression.expression_df
# Out:
# gene_ID    ENSG00000237851  ENSG00000257527  ENSG00000225193  ENSG00000271402  \
# id
# S_MSA_10          0.000000                0         0.000000                0
# P_P9_1            0.000000                0         0.000000                0
# P_P4_14           0.000000                0         0.000000                0
# P_P9_2            0.000000                0         0.000000                0
# P_P4_12           0.000000                0         0.203649                0
# P_P4_13           0.000000                0         0.000000                0
# P_P4_10           0.000000                0         0.000000                0
# P_P4_11           0.000000                0         0.000000                0
# M_M2nd_25         0.000000                0         0.000000                0
# M_M2nd_24         0.000000                0         0.000000                0
# M_M2nd_27         0.000000                0         0.000000                0
# M_M2nd_26         0.000000                0         0.000000                0
# M_M2nd_20         0.000000                0         0.000000                0
# M_M2nd_09         0.000000                0         0.000000                0
# M_M2nd_22         0.000000                0         0.000000                0
# M_M2nd_29         0.000000                0         0.000000                0
# M_M2nd_28         0.000000                0         0.000000                0
# S_MSA_06          0.000000                0         0.000000                0
# S_MSA_07          0.000000                0         0.000000                0
# S_MSA_04          0.000000                0         0.000000                0
# S_MSA_02          0.000000                0         0.000000                0
# S_MSA_03          0.000000                0         0.000000                0
# M_M1_10           0.000000                0         0.000000                0
# S_MSA_01          0.000000                0         0.000000                0
# S_MSA_08          0.000000                0         0.000000                0
# S_MSA_09          0.000000                0         0.000000                0
# S_MSA_17          0.000000                0         0.000000                0
# S_MSA_16          0.000000                0         0.000000                0
# P_P9_3            0.000000                0         0.000000                0
# S_MSA_12          0.000000                0         0.000000                0
# M_M3_14           0.000000                0         0.000000                0
# M_M3_13           0.000000                0         0.000000                0
# M_M3_12           0.000000                0         0.000000                0
# M_M6_3            0.000000                0         0.000000                0
# P_P7_1            0.000000                0         0.000000                0
# M_M1_11           0.000000                0         0.000000                0
# P_P7_6            0.361340                0         0.000000                0
# M_M6_4            0.000000                0         0.000000                0
# M_M1_12           0.000000                0         0.000000                0
# S_MSA_18          0.000000                0         0.000000                0
# M_M2nd_32         0.000000                0         0.000000                0
# M_M4_9            0.000000                0         0.000000                0
# M_M2nd_30         0.000000                0         0.000000                0
# M_M2nd_31         0.000000                0         0.000000                0
# M_M4_4            0.000000                0         0.000000                0
# M_M4_5            0.000000                0         0.000000                0
# S_MSA_13          0.000000                0         0.000000                0
# M_M4_7            1.103224                0         0.000000                0
# S_MSA_15          0.000000                0         0.000000                0
# M_M4_3            0.000000                0         0.000000                0
# P_P1_02           0.000000                0         0.000000                0
# P_P1_03           0.000000                0         0.000000                0
# N_CVN_17          0.000000                0         0.000000                0
# P_P1_06           0.000000                0         0.000000                0
# P_P7_4            0.000000                0         0.378466                0
# S_MSA_14          0.000000                0         0.000000                0
# P_P1_07           0.000000                0         0.000000                0
# P_P8_1            0.000000                0         0.000000                0
# P_P8_2            0.000000                0         0.000000                0
# M_M2nd_08         0.000000                0         0.000000                0
#                        ...              ...              ...              ...
#
# gene_ID    ENSG00000254681  ENSG00000228477  ENSG00000159733  ENSG00000220785  \
# id
# S_MSA_10          0.000000         0.000000         0.000000         0.000000
# P_P9_1            0.000000         0.292186         0.000000         0.919445
# P_P4_14           0.000000         0.275686         0.000000         0.000000
# P_P9_2            0.000000         0.247384         0.000000         1.001820
# P_P4_12           0.000000         0.403581         0.000000         0.000000
# P_P4_13           0.000000         0.245697         0.000000         0.816606
# P_P4_10           0.404109         0.400503         0.000000         0.000000
# P_P4_11           0.000000         0.000000         0.000000         0.000000
# M_M2nd_25         0.000000         0.000000         0.000000         0.000000
# M_M2nd_24         0.000000         0.000000         0.000000         0.000000
# M_M2nd_27         0.000000         0.000000         0.000000         0.000000
# M_M2nd_26         0.000000         0.000000         0.000000         0.000000
# M_M2nd_20         0.000000         0.000000         0.000000         0.000000
# M_M2nd_09         0.000000         0.000000         0.000000         0.000000
# M_M2nd_22         0.000000         0.196529         0.000000         0.000000
# M_M2nd_29         0.000000         0.000000         0.000000         0.000000
# M_M2nd_28         0.000000         0.285564         0.000000         0.000000
# S_MSA_06          0.000000         0.000000         0.000000         0.000000
# S_MSA_07          0.000000         0.000000         0.000000         0.000000
# S_MSA_04          0.000000         0.000000         0.000000         0.000000
# S_MSA_02          0.000000         0.000000         0.000000         0.000000
# S_MSA_03          0.000000         0.000000         0.000000         0.000000
# M_M1_10           0.000000         0.000000         0.000000         0.000000
# S_MSA_01          0.000000         0.000000         0.000000         0.000000
# S_MSA_08          0.000000         0.000000         0.000000         0.000000
# S_MSA_09          0.220417         0.000000         0.000000         0.000000
# S_MSA_17          0.000000         0.000000         0.000000         0.000000
# S_MSA_16          0.000000         0.000000         0.000000         0.000000
# P_P9_3            0.000000         0.292664         0.000000         0.000000
# S_MSA_12          0.000000         0.000000         0.000000         0.000000
# M_M3_14           0.000000         0.000000         0.000000         0.000000
# M_M3_13           0.000000         0.000000         0.000000         0.000000
# M_M3_12           0.304830         0.000000         0.000000         0.000000
# M_M6_3            0.000000         0.000000         0.000000         0.000000
# P_P7_1            0.000000         0.000000         0.000000         0.000000
# M_M1_11           0.000000         0.150106         0.000000         0.000000
# P_P7_6            0.649421         0.233953         0.000000         0.000000
# M_M6_4            0.000000         0.000000         0.000000         0.000000
# M_M1_12           0.000000         0.000000         0.000000         0.000000
# S_MSA_18          0.000000         0.000000         0.000000         0.000000
# M_M2nd_32         0.000000         0.000000         0.000000         0.000000
# M_M4_9            0.000000         0.000000         0.000000         0.000000
# M_M2nd_30         0.000000         0.000000         0.000000         0.000000
# M_M2nd_31         0.000000         0.000000         0.000000         0.000000
# M_M4_4            0.000000         0.000000         0.000000         0.000000
# M_M4_5            0.804178         0.000000         0.000000         0.000000
# S_MSA_13          0.000000         0.000000         0.000000         0.000000
# M_M4_7            0.000000         0.163784         0.000000         0.000000
# S_MSA_15          0.000000         0.000000         0.000000         0.000000
# M_M4_3            0.868814         0.000000         0.000000         0.000000
# P_P1_02           0.501463         0.361731         0.000000         0.000000
# P_P1_03           0.000000         0.181594         0.000000         0.000000
# N_CVN_17          0.383939         0.000000         0.000000         0.000000
# P_P1_06           0.000000         0.000000         0.000000         0.919576
# P_P7_4            0.000000         0.446736         0.000000         0.000000
# S_MSA_14          0.000000         0.000000         0.000000         0.000000
# P_P1_07           0.182951         0.000000         0.000000         0.000000
# P_P8_1            0.000000         0.219165         0.317103         0.000000
# P_P8_2            0.690013         0.186945         0.000000         0.000000
# M_M2nd_08         0.000000         0.000000         0.000000         0.000000
#                        ...              ...              ...              ...
#
# gene_ID    ENSG00000125409  ENSG00000034063  ENSG00000237472  ENSG00000140575  \
# id
# S_MSA_10          0.000000         0.000000         0.000000         0.000000
# P_P9_1            0.000000         0.233416         0.000000         0.853646
# P_P4_14           0.000000         0.000000         0.000000         1.414262
# P_P9_2            0.000000         0.000000         0.000000         1.614222
# P_P4_12           0.000000         1.378214         0.000000         1.595169
# P_P4_13           0.000000         1.047981         0.000000         1.116706
# P_P4_10           0.000000         0.511655         0.000000         1.449091
# P_P4_11           0.000000         0.928697         0.000000         1.101029
# M_M2nd_25         0.000000         0.000000         0.000000         0.000000
# M_M2nd_24         0.000000         0.000000         0.000000         0.000000
# M_M2nd_27         0.000000         0.000000         0.000000         0.000000
# M_M2nd_26         0.000000         0.000000         0.000000         0.000000
# M_M2nd_20         0.000000         0.000000         0.000000         0.348683
# M_M2nd_09         0.000000         0.000000         0.000000         0.000000
# M_M2nd_22         0.000000         0.000000         0.000000         0.000000
# M_M2nd_29         0.000000         0.000000         0.000000         0.000000
# M_M2nd_28         0.000000         0.000000         0.000000         0.000000
# S_MSA_06          0.000000         0.000000         0.000000         0.000000
# S_MSA_07          0.000000         0.000000         0.000000         0.000000
# S_MSA_04          1.590292         1.039193         0.000000         0.000000
# S_MSA_02          0.000000         0.000000         0.000000         0.000000
# S_MSA_03          0.000000         0.000000         0.000000         1.996689
# M_M1_10           0.000000         0.000000         0.000000         0.000000
# S_MSA_01          0.000000         0.000000         0.000000         0.000000
# S_MSA_08          0.000000         0.000000         0.000000         0.000000
# S_MSA_09          0.000000         0.000000         0.000000         0.000000
# S_MSA_17          0.000000         0.000000         0.000000         0.000000
# S_MSA_16          0.000000         0.000000         0.000000         0.755249
# P_P9_3            0.000000         0.906811         0.000000         1.301994
# S_MSA_12          0.000000         0.000000         0.000000         0.000000
# M_M3_14           0.000000         0.000000         0.000000         0.000000
# M_M3_13           0.000000         0.742259         0.000000         0.000000
# M_M3_12           0.000000         0.000000         0.000000         0.000000
# M_M6_3            0.000000         0.000000         0.000000         0.000000
# P_P7_1            0.000000         0.705456         0.000000         0.842115
# M_M1_11           0.000000         0.223456         0.000000         0.000000
# P_P7_6            0.000000         1.086616         0.000000         1.104646
# M_M6_4            0.000000         0.000000         0.000000         0.000000
# M_M1_12           0.000000         0.000000         0.000000         0.000000
# S_MSA_18          0.000000         0.000000         0.000000         1.063519
# M_M2nd_32         0.000000         0.000000         0.000000         0.000000
# M_M4_9            0.000000         0.000000         0.000000         0.000000
# M_M2nd_30         0.000000         0.000000         0.000000         0.000000
# M_M2nd_31         0.000000         0.000000         0.000000         0.000000
# M_M4_4            0.000000         0.319653         0.000000         0.763680
# M_M4_5            0.000000         0.000000         0.000000         0.737072
# S_MSA_13          0.000000         1.640449         0.000000         0.826850
# M_M4_7            0.000000         0.000000         0.000000         0.000000
# S_MSA_15          0.000000         0.000000         0.000000         0.000000
# M_M4_3            0.000000         0.000000         0.000000         0.578687
# P_P1_02           0.000000         1.432888         0.000000         1.435808
# P_P1_03           0.000000         1.023256         0.000000         1.198007
# N_CVN_17          0.000000         1.150805         0.216597         0.831376
# P_P1_06           0.000000         1.014836         0.000000         1.054818
# P_P7_4            0.000000         1.248947         0.000000         0.919453
# S_MSA_14          0.000000         0.000000         0.000000         0.000000
# P_P1_07           0.000000         1.192063         0.000000         1.137701
# P_P8_1            0.000000         1.471937         0.000000         1.582900
# P_P8_2            0.000000         1.009106         0.000000         1.447553
# M_M2nd_08         0.000000         0.000000         0.000000         1.983647
#                        ...              ...              ...              ...
#
# gene_ID    ENSG00000254673  ENSG00000106992  ENSG00000167074  ENSG00000143479  \
# id
# S_MSA_10          0.441947         0.000000         0.000000         0.000000
# P_P9_1            0.000000         1.355984         0.000000         0.000000
# P_P4_14           0.000000         0.000000         0.000000         0.000000
# P_P9_2            0.000000         0.000000         0.000000         0.000000
# P_P4_12           0.823780         0.000000         0.000000         0.000000
# P_P4_13           0.000000         0.923456         0.000000         0.000000
# P_P4_10           1.750443         0.000000         0.000000         0.000000
# P_P4_11           1.613205         0.297647         0.000000         0.000000
# M_M2nd_25         0.000000         2.435548         0.000000         0.000000
# M_M2nd_24         0.000000         0.000000         0.000000         0.000000
# M_M2nd_27         0.000000         0.000000         0.000000         0.000000
# M_M2nd_26         0.000000         0.202664         0.000000         0.000000
# M_M2nd_20         0.000000         0.000000         0.000000         0.000000
# M_M2nd_09         0.000000         0.000000         0.000000         0.000000
# M_M2nd_22         0.000000         0.000000         0.000000         0.000000
# M_M2nd_29         0.000000         0.619188         0.000000         0.000000
# M_M2nd_28         0.000000         0.000000         0.000000         0.000000
# S_MSA_06          1.824732         0.803690         0.000000         0.000000
# S_MSA_07          1.745239         0.951727         0.000000         0.000000
# S_MSA_04          0.648695         1.933000         0.000000         0.000000
# S_MSA_02          2.505317         0.000000         0.000000         0.000000
# S_MSA_03          0.000000         0.000000         0.000000         0.000000
# M_M1_10           0.000000         1.006625         0.000000         0.000000
# S_MSA_01          0.000000         2.003808         0.000000         0.000000
# S_MSA_08          0.000000         0.289902         0.000000         0.000000
# S_MSA_09          0.000000         0.000000         0.000000         0.000000
# S_MSA_17          0.000000         0.000000         0.000000         0.000000
# S_MSA_16          0.360332         0.341251         0.000000         0.000000
# P_P9_3            0.000000         0.000000         0.000000         0.000000
# S_MSA_12          1.895404         0.000000         0.000000         0.000000
# M_M3_14           1.687273         0.000000         0.000000         0.000000
# M_M3_13           0.657571         0.998822         0.000000         0.000000
# M_M3_12           0.000000         1.904700         0.000000         0.000000
# M_M6_3            0.000000         0.000000         0.000000         0.000000
# P_P7_1            0.000000         1.230105         0.000000         0.000000
# M_M1_11           0.000000         1.447192         0.000000         0.000000
# P_P7_6            0.666705         0.000000         0.000000         0.000000
# M_M6_4            0.000000         0.372945         0.000000         0.000000
# M_M1_12           0.755837         1.357737         0.000000         1.436146
# S_MSA_18          1.193236         1.007837         0.000000         0.000000
# M_M2nd_32         0.000000         0.462564         0.000000         0.000000
# M_M4_9            0.000000         0.000000         0.000000         0.000000
# M_M2nd_30         0.000000         0.000000         0.000000         0.000000
# M_M2nd_31         0.000000         0.000000         0.000000         0.000000
# M_M4_4            0.000000         0.549987         0.000000         0.000000
# M_M4_5            1.262246         0.644757         0.000000         0.000000
# S_MSA_13          0.479066         1.808761         0.000000         0.000000
# M_M4_7            1.715476         0.000000         0.000000         0.000000
# S_MSA_15          0.000000         1.697166         0.000000         0.000000
# M_M4_3            0.000000         0.000000         0.000000         0.000000
# P_P1_02           0.000000         1.331503         0.000000         0.000000
# P_P1_03           0.978182         1.062759         0.000000         0.000000
# N_CVN_17          0.842900         1.153685         0.602152         0.000000
# P_P1_06           1.738117         0.000000         0.000000         0.000000
# P_P7_4            1.754008         0.490690         0.000000         0.000000
# S_MSA_14          0.000000         1.428236         0.000000         0.000000
# P_P1_07           0.000000         1.483994         0.000000         0.000000
# P_P8_1            0.000000         1.009839         0.000000         0.000000
# P_P8_2            0.000000         1.300105         0.000000         0.000000
# M_M2nd_08         0.000000         0.000000         0.000000         0.000000
#                        ...              ...              ...              ...
#
# gene_ID    ENSG00000225118  ENSG00000119514  ENSG00000223861  ENSG00000108510  \
# id
# S_MSA_10                 0         0.000000         0.000000         0.786171
# P_P9_1                   0         0.163835         0.184955         0.000000
# P_P4_14                  0         0.000000         0.227558         0.906800
# P_P9_2                   0         0.000000         0.000000         0.000000
# P_P4_12                  0         0.000000         0.186982         0.375245
# P_P4_13                  0         0.162517         0.204347         0.784076
# P_P4_10                  0         1.196424         0.000000         0.975786
# P_P4_11                  0         0.000000         0.000000         0.189247
# M_M2nd_25                0         0.000000         0.000000         0.867796
# M_M2nd_24                0         0.000000         0.000000         0.000000
# M_M2nd_27                0         0.000000         0.000000         0.000000
# M_M2nd_26                0         0.000000         0.000000         0.000000
# M_M2nd_20                0         0.000000         0.000000         0.000000
# M_M2nd_09                0         0.000000         0.000000         0.835356
# M_M2nd_22                0         0.000000         0.000000         0.000000
# M_M2nd_29                0         0.000000         0.000000         0.183506
# M_M2nd_28                0         0.000000         0.000000         0.000000
# S_MSA_06                 0         0.000000         0.000000         1.166301
# S_MSA_07                 0         0.000000         0.000000         0.000000
# S_MSA_04                 0         0.000000         0.000000         1.142070
# S_MSA_02                 0         0.000000         0.000000         0.000000
# S_MSA_03                 0         0.000000         0.000000         0.000000
# M_M1_10                  0         0.000000         0.000000         0.000000
# S_MSA_01                 0         0.000000         0.000000         0.999177
# S_MSA_08                 0         0.000000         0.000000         1.016311
# S_MSA_09                 0         0.000000         0.000000         0.498623
# S_MSA_17                 0         0.000000         0.000000         0.000000
# S_MSA_16                 0         0.000000         0.000000         1.761553
# P_P9_3                   0         0.263340         0.224821         0.000000
# S_MSA_12                 0         0.000000         0.000000         0.766319
# M_M3_14                  0         0.000000         0.000000         0.522418
# M_M3_13                  0         0.000000         0.000000         1.024732
# M_M3_12                  0         0.000000         0.000000         0.000000
# M_M6_3                   0         0.000000         0.202844         0.814383
# P_P7_1                   0         0.000000         0.000000         0.000000
# M_M1_11                  0         0.000000         0.000000         0.746604
# P_P7_6                   0         0.000000         0.000000         0.553757
# M_M6_4                   0         0.000000         0.000000         1.305338
# M_M1_12                  0         0.000000         0.000000         0.000000
# S_MSA_18                 0         0.000000         0.000000         1.861963
# M_M2nd_32                0         0.000000         0.000000         0.695564
# M_M4_9                   0         0.000000         0.000000         0.000000
# M_M2nd_30                0         0.000000         0.000000         0.000000
# M_M2nd_31                0         0.000000         0.000000         0.000000
# M_M4_4                   0         0.000000         0.000000         1.474814
# M_M4_5                   0         0.000000         0.000000         0.594551
# S_MSA_13                 0         0.000000         0.000000         0.000000
# M_M4_7                   0         0.000000         0.000000         0.000000
# S_MSA_15                 0         0.000000         0.000000         1.228550
# M_M4_3                   0         0.000000         0.000000         0.410289
# P_P1_02                  0         0.183074         0.199741         0.000000
# P_P1_03                  0         0.229616         0.000000         0.375111
# N_CVN_17                 0         0.000000         0.774267         0.629248
# P_P1_06                  0         0.000000         0.000000         0.000000
# P_P7_4                   0         0.000000         0.320499         0.483025
# S_MSA_14                 0         0.000000         0.000000         1.101452
# P_P1_07                  0         0.000000         0.000000         0.740186
# P_P8_1                   0         0.000000         0.280530         0.000000
# P_P8_2                   0         0.388488         0.000000         0.256051
# M_M2nd_08                0         0.000000         0.000000         0.000000
#                        ...              ...              ...              ...
#
# gene_ID
# id
# S_MSA_10  ...
# P_P9_1    ...
# P_P4_14   ...
# P_P9_2    ...
# P_P4_12   ...
# P_P4_13   ...
# P_P4_10   ...
# P_P4_11   ...
# M_M2nd_25 ...
# M_M2nd_24 ...
# M_M2nd_27 ...
# M_M2nd_26 ...
# M_M2nd_20 ...
# M_M2nd_09 ...
# M_M2nd_22 ...
# M_M2nd_29 ...
# M_M2nd_28 ...
# S_MSA_06  ...
# S_MSA_07  ...
# S_MSA_04  ...
# S_MSA_02  ...
# S_MSA_03  ...
# M_M1_10   ...
# S_MSA_01  ...
# S_MSA_08  ...
# S_MSA_09  ...
# S_MSA_17  ...
# S_MSA_16  ...
# P_P9_3    ...
# S_MSA_12  ...
# M_M3_14   ...
# M_M3_13   ...
# M_M3_12   ...
# M_M6_3    ...
# P_P7_1    ...
# M_M1_11   ...
# P_P7_6    ...
# M_M6_4    ...
# M_M1_12   ...
# S_MSA_18  ...
# M_M2nd_32 ...
# M_M4_9    ...
# M_M2nd_30 ...
# M_M2nd_31 ...
# M_M4_4    ...
# M_M4_5    ...
# S_MSA_13  ...
# M_M4_7    ...
# S_MSA_15  ...
# M_M4_3    ...
# P_P1_02   ...
# P_P1_03   ...
# N_CVN_17  ...
# P_P1_06   ...
# P_P7_4    ...
# S_MSA_14  ...
# P_P1_07   ...
# P_P8_1    ...
# P_P8_2    ...
# M_M2nd_08 ...
#
# [201 rows x 33392 columns]

# %% [markdown]
# #Raw data for splicing, PSI:

# %%
sc_study.splicing.splicing_df
# Out:
# event_name  chr10:100148111:100148265:-@chr10:100147622:100147841:-@chr10:100146958:100147064:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                 0.91
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100174766:100174978:-@chr10:100174489:100174591:-@chr10:100173705:100174052:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                 0.08
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100185575:100185742:-@chr10:100185441|100185477:100185298:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                  NaN
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100186972:100187021:-@chr10:100185575:100185742:-@chr10:100185298:100185477:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                  NaN
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100190328:100190427:-@chr10:100189548:100189646:-@chr10:100189330:100189399:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                 0.93
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                 0.75
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100193697:100193848:-@chr10:100190888:100191048:-@chr10:100190328:100190427:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                 0.95
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100193740:100193848:-@chr10:100190888:100191048:-@chr10:100190328:100190427:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                 0.95
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100193848:100193697|100193740:-@chr10:100190328:100190427:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                  NaN
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:100193848:100193697|100193740:-@chr10:100190888:100191048:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# ...
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:101379802:101380221:-@chr10:101373453:101373681:-@chr10:101372300:101372356:-@chr10:101370642:101371215:-  \
# id
# N_CVN_01                                                  NaN
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                 0.99
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                  NaN
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                 0.09
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                 0.04
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                  NaN
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                   NaN
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                  1.00
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name  chr10:101419619:101419721:+@chr10:101420057:101420239:+@chr10:101421203:101421385:+  \
# id
# N_CVN_01                                                 0.05
# N_CVN_02                                                  NaN
# N_CVN_03                                                  NaN
# N_CVN_04                                                  NaN
# N_CVN_05                                                  NaN
# N_CVN_06                                                  NaN
# N_CVN_07                                                  NaN
# N_CVN_08                                                  NaN
# N_CVN_09                                                  NaN
# N_CVN_10                                                  NaN
# N_CVN_11                                                  NaN
# N_CVN_12                                                  NaN
# N_CVN_13                                                  NaN
# N_CVN_14                                                  NaN
# N_CVN_15                                                  NaN
# N_CVN_16                                                  NaN
# N_CVN_17                                                  NaN
# N_CVN_18                                                  NaN
# N_CVN_19                                                 0.05
# N_CVN_20                                                  NaN
# N_CVN_21                                                  NaN
# N_CVN_22                                                  NaN
# N_CVN_23                                                  NaN
# N_CVN_24                                                  NaN
# N_CVN_25                                                  NaN
# N_CVN_26                                                  NaN
# N_CVN_27                                                  NaN
# N_CVN_28                                                  NaN
# N_CVN_29                                                  NaN
# N_CVN_30                                                  NaN
# N_CVN_31                                                  NaN
# N_CVN_32                                                  NaN
# N_CVN_33                                                  NaN
# N_CVN_34                                                  NaN
# N_CVN_35                                                  NaN
# M_M1_01                                                   NaN
# M_M1_02                                                   NaN
# M_M1_05                                                   NaN
# M_M1_06                                                   NaN
# M_M1_07                                                  0.04
# M_M1_08                                                   NaN
# M_M1_09                                                   NaN
# M_M1_10                                                   NaN
# M_M1_11                                                   NaN
# M_M1_12                                                   NaN
# M_M2_03                                                   NaN
# M_M2_04                                                   NaN
# M_M2_08                                                   NaN
# M_M2_09                                                   NaN
# M_M2_10                                                   NaN
# M_M2_11                                                   NaN
# M_M2_12                                                   NaN
# M_M2nd_01                                                 NaN
# M_M2nd_02                                                 NaN
# M_M2nd_03                                                 NaN
# M_M2nd_04                                                 NaN
# M_M2nd_05                                                 NaN
# M_M2nd_06                                                 NaN
# M_M2nd_07                                                 NaN
# M_M2nd_08                                                 NaN
#                                                           ...
#
# event_name
# id
# N_CVN_01   ...
# N_CVN_02   ...
# N_CVN_03   ...
# N_CVN_04   ...
# N_CVN_05   ...
# N_CVN_06   ...
# N_CVN_07   ...
# N_CVN_08   ...
# N_CVN_09   ...
# N_CVN_10   ...
# N_CVN_11   ...
# N_CVN_12   ...
# N_CVN_13   ...
# N_CVN_14   ...
# N_CVN_15   ...
# N_CVN_16   ...
# N_CVN_17   ...
# N_CVN_18   ...
# N_CVN_19   ...
# N_CVN_20   ...
# N_CVN_21   ...
# N_CVN_22   ...
# N_CVN_23   ...
# N_CVN_24   ...
# N_CVN_25   ...
# N_CVN_26   ...
# N_CVN_27   ...
# N_CVN_28   ...
# N_CVN_29   ...
# N_CVN_30   ...
# N_CVN_31   ...
# N_CVN_32   ...
# N_CVN_33   ...
# N_CVN_34   ...
# N_CVN_35   ...
# M_M1_01    ...
# M_M1_02    ...
# M_M1_05    ...
# M_M1_06    ...
# M_M1_07    ...
# M_M1_08    ...
# M_M1_09    ...
# M_M1_10    ...
# M_M1_11    ...
# M_M1_12    ...
# M_M2_03    ...
# M_M2_04    ...
# M_M2_08    ...
# M_M2_09    ...
# M_M2_10    ...
# M_M2_11    ...
# M_M2_12    ...
# M_M2nd_01  ...
# M_M2nd_02  ...
# M_M2nd_03  ...
# M_M2nd_04  ...
# M_M2nd_05  ...
# M_M2nd_06  ...
# M_M2nd_07  ...
# M_M2nd_08  ...
#
# [223 rows x 56830 columns]

# %% [markdown]
# ##parameters established in <code>neural_cell_diff</code> poulate the lists of interactive objects

# %% [markdown]
# ##<b>interactive_pca</b>
#
# runs PCA
#
# group_id is a subset of samples to use<br>
# data_type -designates whether you'd like to do PCA with either splicing or gene expression as features<br>
# featurewise - selects whether you'd like to visualize PCA of samples or of features<br>
# x_pc and y_pc - select the components to display for the x- and y- dimensions<br>
# show_point_labels - draws sample/feature labels<br>
# list_link - a local file path (full path) or a http: link to a list of line-delimited features to use for the PCA<br>
# list_name - contains pre-loaded lists, you can set this to "custom" to use list_link<br>
# savefile - a file to output

# %%
sc_study.interactive_pca()
# Out:
# savefile : data/last.pca.pdf
# y_pc : 3
# data_type : splicing
# featurewise : False
# show_point_labels : False
# x_pc : 1
# list_link :
# list_name : variant
# group_id : neuron_cell
# error with M_M3_10
# error with M_M6_3

# %% [markdown]
# ##<b>interactive_graph</b>
#
# makes a graph where layout of nodes is determined by their covariance in PCA-space
#
# group_id - a subset of samples to use<br>
# data_type - designates whether you'd like to do PCA with either splicing or gene expression as features<br>
# featurewise - selects whether you'd like to visualize samples or of features<br>
# draw_labels - draws sample/feature labels on nodes<br>
# degree_cut - minimum degree for nodes to be included in the output
# cov_std_cut - minimum covariance for two nodes to have an edge
# n_pcs - use the first n_pcs
# feature_of_interest - feature to highlight. recommended that you paste into this box, rather than type directly
# use_pc_X - de-select to exclude component X
# list_name - contains pre-loaded lists and custom lists added with custom "list_link" in interactive_pca<br>
# savefile - a file to output
# weight_fun - a function to apply to covariances before filtering

# %%
sc_study.interactive_graph()
# Out:
# savefile : data/last.graph.pdf
# group_id : ~outlier
# data_type : expression
# featurewise : True
# weight_fun : abs
# use_pc_4 : True
# use_pc_2 : True
# use_pc_3 : True
# use_pc_1 : True
# cov_std_cut : 1.8
# degree_cut : 1
# feature_of_interest : RBFOX2
# draw_labels : False
# list_name : confident_rbps
# n_pcs : 16

# %% [markdown]
# ##<b>interactive_clf</b>
#
# makes a classifier, plots PCA of samples using only important features from the classifier. (default classifier is ExtraTreesClassifier, extremely randomized forests)
#
# data_type - designates whether you'd like to do PCA with either splicing or gene expression as features<br>
# list_name - contains pre-loaded lists and custom lists added with custom "list_link" in interactive_pca<br>
# group_id - a subset of samples to use<br>
# categorical_variable - a column in expression.sample_descriptors upon which to train a classifier<br>
# feature_score_std_cutoff - mean + (this x std) is used to select the top features<br>
# safefile - a file to output

# %%
sc_study.interactive_clf()
# Out:
# savefile : data/last.clf.pdf
# group_id : ~outlier
# data_type : expression
# categorical_variable : M_cell
# list_name : variant
# feature_score_std_cutoff : 2.0
# Initializing predictors for M_cell
# Fitting a classifier for trait M_cell... please wait.
# Finished...
# Scoring classifier: ExtraTreesClassifier for trait: M_cell... please wait.
# Finished...
# retrieve this predictor with:
# prd=study.expression.get_predictor('variant', '~outlier', 'M_cell')
# pca=prd('M_cell', feature_score_std_cutoff=2.000000)
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    0.0s finished

# %%
print "here are the pooled samples\n"
import pandas as pd
for i in sc_study.sample_info.index[pd.Series(sc_study.sample_info['is_pooled'], dtype='bool')]:
    print "\t", i
# Out:
# here are the pooled samples
#
# 	M_M2_05
# 	M_M2nd_13
# 	M_M2nd_21
# 	P_M2nd_33
# 	P_M2nd_34
# 	N_CVN_17
# 	N_CVN_35
# 	S_MSA_19
# 	S_MSA_29

# %% [markdown]
# ##<b>interatctive_localZ</b>
#
# runs localZ comparision on 2 RNAseq samples... works on any datatype but only really has meaning on expression.<br>
# sample1 - name of sample on x-axis<br>
# sample2 - name of sample on y-axis<br>
# pCut - p-value cutoff, must be a float. recommended that you paste here, not type in this box.<br>
#
# running this updates sc_study.localZ_result with a dataFrame of the results to be parsed by the user

# %%
sc_study.interactive_localZ()
# Out:
# sample1 : replaceme
# pCut : 0.01
# data_type : expression
# sample2 : replaceme
# sample: replaceme, is not in expression DataFrame, try a different sample ID

# %%
sc_study.localZ_result
# Out:
#                   rank  log2Ratio  localMean  localStd        pValue  isSig  \
# gene_ID
# ENSG00000220785    418   0.204153  -0.074472  0.629507   6369.501096  False
# ENSG00000034063   5721   0.098194  -0.163993  0.397732   8947.335245  False
# ENSG00000140575   7505  -0.349715  -0.121749  0.238659  11742.023421  False
# ENSG00000254673   6532  -0.900368  -0.150624  0.321584    907.925895  False
# ENSG00000106992   2003  -0.883352  -0.220418  0.744643   3995.680485  False
# ENSG00000119514   6008  -0.780213  -0.164083  0.373755   3040.597395  False
# ENSG00000108510   4846  -0.156939  -0.189505  0.490895   8988.795810  False
# ENSG00000085832   7127  -0.019240  -0.134601  0.257175  15549.754435  False
# ENSG00000261118    253   0.327599  -0.074472  0.629507   5728.755750  False
# ENSG00000121690   6367  -0.386748  -0.155941  0.332717  10448.994746  False
# ENSG00000081842   1429   0.563782  -0.162371  0.770549   3681.283862  False
# ENSG00000039560   8100  -0.060417  -0.117451  0.203581  20886.459956  False
# ENSG00000111775  10976  -0.024313  -0.033637  0.074049  59249.689743  False
# ENSG00000167881   5217  -0.381570  -0.190366  0.446589   9035.112509  False
# ENSG00000197372   7712   0.082133  -0.119618  0.228731  13103.265292  False
# ENSG00000181555   6239  -0.223808  -0.150975  0.357327  12121.544331  False
# ENSG00000214940   6901   0.017082  -0.143739  0.279193  13418.104711  False
# ENSG00000137312   3653  -1.193034  -0.204439  0.638103   2087.122890  False
# ENSG00000139579   8516  -0.265572  -0.108458  0.169503  16978.673405  False
# ENSG00000105677   9680  -0.060817  -0.074243  0.117345  37440.141139  False
# ENSG00000172071   3523   0.224018  -0.207007  0.656297   5431.056295  False
# ENSG00000176148   2672  -0.425260  -0.190788  0.733344   5729.801563  False
# ENSG00000111817   7402  -0.096741  -0.119975  0.243966  18044.566347  False
# ENSG00000138686   5220  -0.389329  -0.190201  0.446598   8965.170785  False
# ENSG00000172613    700  -0.332567  -0.074472  0.629507   6458.678339  False
# ENSG00000188636   3472   0.811145  -0.190448  0.669769   2158.296640  False
# ENSG00000233476  11064   0.044297  -0.033637  0.074049  34324.094111  False
# ENSG00000270113   7292   0.330735  -0.124059  0.251199   3418.563223  False
# ENSG00000064490   7558  -0.088767  -0.123126  0.234250  18676.486684  False
# ENSG00000099991   1906  -0.290516  -0.222295  0.756502   5821.970993  False
# ENSG00000115414   2409  -0.472082  -0.194566  0.737359   5587.374508  False
# ENSG00000135686   1790  -0.416170  -0.214163  0.756222   5642.889786  False
# ENSG00000053770   8897   0.054141  -0.094844  0.148840  18003.388473  False
# ENSG00000260345   3018  -0.938587  -0.188596  0.712045   3566.402007  False
# ENSG00000269131   7911  -0.048574  -0.120155  0.215955  19383.134262  False
# ENSG00000213976   1772  -1.281339  -0.216706  0.754254   2165.186904  False
# ENSG00000179091   6776  -0.238272  -0.144335  0.296207  14197.473307  False
# ENSG00000142546   3134  -0.678246  -0.192976  0.712042   4923.596504  False
# ENSG00000109171   2889  -1.035209  -0.185275  0.717005   3054.896830  False
# ENSG00000143190   4165  -0.344100  -0.187924  0.581364   7337.144011  False
# ENSG00000179988   3040   0.207785  -0.191473  0.711499   5309.997263  False
# ENSG00000120306   9125  -0.104952  -0.088536  0.139157  31558.583472  False
# ENSG00000152022   3263   1.439525  -0.192271  0.696531    408.226530  False
# ENSG00000138771   2320  -0.220497  -0.205345  0.737924   5991.600352  False
# ENSG00000179163   2879  -0.845813  -0.184478  0.719659   4028.491567  False
# ENSG00000236714   4783  -0.652258  -0.190004  0.509777   5750.663892  False
# ENSG00000198901   7823  -0.064297  -0.118845  0.226257  18985.527055  False
# ENSG00000025770   2994  -1.348303  -0.182646  0.712977   1629.850920  False
# ENSG00000040633   3133   0.799237  -0.193581  0.711746   2348.576044  False
# ENSG00000117222  10043   0.106058  -0.033637  0.074049  10076.393494  False
# ENSG00000164715   3582  -0.086822  -0.206028  0.658133   6610.097841  False
# ENSG00000162585    207  -0.479314  -0.074472  0.629507   5712.621467  False
# ENSG00000260257  10465  -0.050353  -0.033637  0.074049  58218.712458  False
# ENSG00000091490   4000  -0.997151  -0.182881  0.613937   2989.093643  False
# ENSG00000258016   8751  -0.047766  -0.100084  0.158395  26436.992479  False
# ENSG00000123636   6033  -0.138440  -0.158209  0.370987  11903.379143  False
# ENSG00000253900   2950   0.700587  -0.182789  0.716054   2885.450147  False
# ENSG00000263986  10193   0.014580  -0.033637  0.074049  48312.564384  False
# ENSG00000196826   6706  -0.058049  -0.145785  0.301443  14061.948733  False
# ENSG00000092036   7867  -0.247923  -0.118681  0.219516  16939.805973  False
#                    ...        ...        ...       ...           ...    ...
#
#                  meanExpression    localZ  P_M2nd_34  P_M2nd_33
# gene_ID
# ENSG00000220785        0.231022  0.442609   0.214704   0.247341
# ENSG00000034063        0.751718  0.659206   0.726145   0.777290
# ENSG00000140575        1.000505 -0.955195   1.121178   0.879832
# ENSG00000254673        0.854851 -2.331414   1.113268   0.596434
# ENSG00000106992        0.383386 -0.890271   0.497224   0.269548
# ENSG00000119514        0.785056 -1.648488   0.992310   0.577803
# ENSG00000108510        0.655248  0.066340   0.690852   0.619643
# ENSG00000085832        0.943139  0.448568   0.949428   0.936850
# ENSG00000261118        0.211900  0.638708   0.187944   0.235856
# ENSG00000121690        0.834459 -0.693704   0.945642   0.723276
# ENSG00000081842        0.332429  0.942385   0.268289   0.396569
# ENSG00000039560        1.103766  0.280153   1.126874   1.080657
# ENSG00000111775        2.714205  0.125915   2.737075   2.691335
# ENSG00000167881        0.692883 -0.428144   0.783980   0.601785
# ENSG00000197372        1.037649  0.882047   1.008121   1.067178
# ENSG00000181555        0.814942 -0.203826   0.878027   0.751856
# ENSG00000214940        0.907391  0.576021   0.902019   0.912762
# ENSG00000137312        0.533189 -1.549273   0.741890   0.324489
# ENSG00000139579        1.184834 -0.926910   1.293579   1.076088
# ENSG00000105677        1.497486  0.114422   1.529044   1.465927
# ENSG00000172071        0.520914  0.656753   0.480552   0.561276
# ENSG00000176148        0.444230 -0.319730   0.509232   0.379227
# ENSG00000111817        0.987444  0.095235   1.020539   0.954350
# ENSG00000138686        0.693184 -0.445876   0.786152   0.600215
# ENSG00000172613        0.263312 -0.409994   0.293528   0.233097
# ENSG00000188636        0.517093  1.495431   0.375439   0.658746
# ENSG00000233476        3.384901  1.052464   3.332939   3.436862
# ENSG00000270113        0.970942  1.810494   0.860133   1.081751
# ENSG00000064490        1.012329  0.146678   1.043463   0.981196
# ENSG00000099991        0.374703 -0.090180   0.412303   0.337103
# ENSG00000115414        0.422787 -0.376366   0.491349   0.354225
# ENSG00000135686        0.365201 -0.267127   0.417513   0.312889
# ENSG00000053770        1.272073  1.000976   1.248207   1.295940
# ENSG00000260345        0.474555 -1.053292   0.623699   0.325411
# ENSG00000269131        1.070272  0.331463   1.088288   1.052256
# ENSG00000213976        0.363171 -1.411506   0.514621   0.211722
# ENSG00000179091        0.887847 -0.317132   0.960999   0.814696
# ENSG00000142546        0.485694 -0.681519   0.597804   0.373583
# ENSG00000109171        0.463707 -1.185395   0.623285   0.304129
# ENSG00000143190        0.584367 -0.268638   0.653728   0.515006
# ENSG00000179988        0.475729  0.561150   0.441529   0.509928
# ENSG00000120306        1.325617 -0.117967   1.373813   1.277420
# ENSG00000152022        0.496298  2.342746   0.267379   0.725217
# ENSG00000138771        0.414207 -0.020533   0.445799   0.382616
# ENSG00000179163        0.462953 -0.918956   0.594903   0.331002
# ENSG00000236714        0.648718 -0.906776   0.792917   0.504520
# ENSG00000198901        1.054674  0.241087   1.078172   1.031176
# ENSG00000025770        0.472816 -1.634914   0.678965   0.266666
# ENSG00000040633        0.485659  1.394904   0.354472   0.616845
# ENSG00000117222        1.644935  1.886527   1.584499   1.705370
# ENSG00000164715        0.526679  0.181127   0.542522   0.510836
# ENSG00000162585        0.203370 -0.643109   0.236846   0.169894
# ENSG00000260257        1.900572 -0.225748   1.933735   1.867408
# ENSG00000091490        0.566992 -1.326308   0.755491   0.378492
# ENSG00000258016        1.238020  0.330304   1.258512   1.217527
# ENSG00000123636        0.787534  0.053285   0.825291   0.749777
# ENSG00000253900        0.469012  1.233672   0.357320   0.580704
# ENSG00000263986        1.717582  0.651147   1.708903   1.726260
# ENSG00000196826        0.878815  0.291054   0.896493   0.861137
# ENSG00000092036        1.060964 -0.588761   1.151903   0.970026
#                             ...       ...        ...        ...
#
# [11085 rows x 10 columns]
