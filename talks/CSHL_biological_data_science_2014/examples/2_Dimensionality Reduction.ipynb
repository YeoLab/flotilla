# %% [markdown]
# ##In this notebook:
# ###Explore variation in samples with principal components analysis (PCA)
# ####Perform PCA on subsets of features
# ####Remove outliers manually
# ####Specify new subsets of data

# %% [markdown]
# ###The following functions are introduced:
# <br>
#
#   * `study.interactive_pca` and `study.plot_pca`<br>
#      These funcitons perform [Principal Components Ananlysis](http://scikit-learn.org/stable/modules/decomposition.html) on user-selected subsets of samples and features. Samples are colored according to a dictionary saved in the [Create A New Study](1_Create%20A%20New%20Study.ipynb#metadata) notebook.
#
#   * `study.drop_outliers`<br>
#      After setting the `outlier` attribute in `study.metadata.data` the samples labelled outliers are removed from `study.expression.data` and `study.splicing.data`
#
#   * `study.plot_gene` and `study.plot_event`<br>
#      These plot the distribution of gene expression or $\psi$ in each phenotype.
#
#   * `study.merge_boolean_metadata_columns` takes mulitiple boolean (True/False) columns and returns the logical OR of these columns.

# %%
import css_styling
# Out:
# <link rel="stylesheet" href="http://bootswatch.com/paper/bootstrap.css">

# %%
import flotilla

# %%
# !ls /root/flotilla_projects/
# Out:
# hb9   hg19_chr22  neural_diff	     neural_diff_demo  test_data
# hg19  mm10	  neural_diff_chr22  t.json

# %%
study = flotilla.embark('http://sauron.ucsd.edu/flotilla_projects/neural_diff/datapackage.json')
# Out:
# 2014-11-02 04:47:27	Parsing datapackage to create a Study object
# 2014-11-02 04:48:47	Initializing Study
# 2014-11-02 04:48:47	Initializing Predictor configuration manager for Study
# 2014-11-02 04:48:47	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2014-11-02 04:48:47	Added ExtraTreesClassifier to default predictors
# 2014-11-02 04:48:47	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2014-11-02 04:48:47	Added ExtraTreesRegressor to default predictors
# 2014-11-02 04:48:47	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2014-11-02 04:48:47	Added GradientBoostingClassifier to default predictors
# 2014-11-02 04:48:47	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2014-11-02 04:48:47	Added GradientBoostingRegressor to default predictors
# 2014-11-02 04:48:47	Loading metadata
# 2014-11-02 04:48:47	Loading species metadata from ~/flotilla_packages
# samples had too few mapped reads (<5.0e+05 reads):
# 	M_M2nd_23, M_M2nd_30, M_M2nd_31, M_M2nd_32, M_M3_10, P_P4_2, P_P8_12, P_P8_3, P_P8_4, P_P8_7, P_P8_8, P_P8_9, S_MSA_25
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-1aaa1bdab4dd> in <module>()
# ----> 1 study = flotilla.embark('http://sauron.ucsd.edu/flotilla_projects/neural_diff/datapackage.json')
#
# /home/root/ipython/src/flotilla/flotilla/__init__.pyc in embark(study_name, load_species_data)
#      37     except IOError:
#      38         return Study.from_datapackage_url(study_name,
# ---> 39                                           load_species_data=load_species_data)
#
# /home/root/ipython/src/flotilla/flotilla/data_model/study.pyc in from_datapackage_url(cls, datapackage_url, load_species_data, species_data_package_base_url)
#     367         return cls.from_datapackage(
#     368             data_package, load_species_data=load_species_data,
# --> 369             species_datapackage_base_url=species_data_package_base_url)
#     370
#     371     @classmethod
#
# /home/root/ipython/src/flotilla/flotilla/data_model/study.pyc in from_datapackage(cls, datapackage, datapackage_dir, load_species_data, species_datapackage_base_url)
#     477             sources=sources,
#     478             version=version,
# --> 479             **kwargs)
#     480         return study
#     481
#
# /home/root/ipython/src/flotilla/flotilla/data_model/study.pyc in __init__(self, sample_metadata, version, expression_data, expression_feature_data, expression_feature_rename_col, expression_feature_ignore_subset_cols, expression_log_base, expression_thresh, expression_plus_one, splicing_data, splicing_feature_data, splicing_feature_rename_col, splicing_feature_ignore_subset_cols, mapping_stats_data, mapping_stats_number_mapped_col, mapping_stats_min_reads, spikein_data, spikein_feature_data, drop_outliers, species, gene_ontology_data, predictor_config_manager, metadata_pooled_col, metadata_phenotype_col, metadata_phenotype_order, metadata_phenotype_to_color, metadata_phenotype_to_marker, license, title, sources, default_sample_subset, default_feature_subset, metadata_minimum_samples)
#     252             sys.stdout.write('{}\tLoading species metadata from '
#     253                              '~/flotilla_packages\n'.format(timestamp()))
# --> 254             species_kws = self.load_species_data(self.species, self.readers)
#     255
#     256             if expression_feature_data is None:
#
# /home/root/ipython/src/flotilla/flotilla/data_model/study.pyc in load_species_data(species, readers, species_datapackage_base_url)
#     505                 name = resource['name']
#     506                 dfs[name] = reader(filename,
# --> 507                                    compression=compression)
#     508                 other_keys = set(resource.keys()).difference(
#     509                     DATAPACKAGE_RESOURCE_COMMON_KWS)
#
# /home/root/ipython/src/flotilla/flotilla/util.pyc in load_csv(file_name, compression)
#     261
#     262 def load_csv(file_name, compression=None):
# --> 263     return pd.read_csv(file_name, index_col=0, compression=compression)
#     264
#     265
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     242         return parser
#     243
# --> 244     return parser.read()
#     245
#     246 _parser_defaults = {
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     701         index, columns, col_dict = self._create_index(ret)
#     702
# --> 703         df = DataFrame(col_dict, columns=columns, index=index)
#     704
#     705         if self.squeeze and len(df.columns) == 1:
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     201                                  dtype=dtype, copy=copy)
#     202         elif isinstance(data, dict):
# --> 203             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     204         elif isinstance(data, ma.MaskedArray):
#     205             import numpy.ma.mrecords as mrecords
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     325
#     326         return _arrays_to_mgr(arrays, data_names, index, columns,
# --> 327                               dtype=dtype)
#     328
#     329     def _init_ndarray(self, values, index, columns, dtype=None,
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    4628     axes = [_ensure_index(columns), _ensure_index(index)]
#    4629
# -> 4630     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    4631
#    4632
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/internals.pyc in create_block_manager_from_arrays(arrays, names, axes)
#    3233 def create_block_manager_from_arrays(arrays, names, axes):
#    3234     try:
# -> 3235         blocks = form_blocks(arrays, names, axes)
#    3236         mgr = BlockManager(blocks, axes)
#    3237         mgr._consolidate_inplace()
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/internals.pyc in form_blocks(arrays, names, axes)
#    3320     if len(object_items) > 0:
#    3321         object_blocks = _simple_blockify(
# -> 3322             object_items, np.object_)
#    3323         blocks.extend(object_blocks)
#    3324
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _simple_blockify(tuples, dtype)
#    3344     not None, coerce to this dtype
#    3345     """
# -> 3346     values, placement = _stack_arrays(tuples, dtype)
#    3347
#    3348     # CHECK DTYPE?
#
# /usr/local/miniconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _stack_arrays(tuples, dtype)
#    3408     shape = (len(arrays),) + _shape_compat(first)
#    3409
# -> 3410     stacked = np.empty(shape, dtype=dtype)
#    3411     for i, arr in enumerate(arrays):
#    3412         stacked[i] = _asarray_compat(arr)
#
# MemoryError:

# %%
study = flotilla.embark("neural_diff_demo")
# Out:
# 2014-11-02 04:31:48	Reading datapackage from /root/flotilla_projects/neural_diff_demo/datapackage.json
# 2014-11-02 04:31:48	Parsing datapackage to create a Study object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-17e74ac4d88a> in <module>()
# ----> 1 study = flotilla.embark("neural_diff_demo")
#
# /home/root/ipython/src/flotilla/flotilla/__init__.pyc in embark(study_name, load_species_data)
#      37     except IOError:
#      38         return Study.from_datapackage_url(study_name,
# ---> 39                                           load_species_data=load_species_data)
#
# /home/root/ipython/src/flotilla/flotilla/data_model/study.pyc in from_datapackage_url(cls, datapackage_url, load_species_data, species_data_package_base_url)
#     364             resources of metadata, expression, and splicing.
#     365         """
# --> 366         data_package = data_package_url_to_dict(datapackage_url)
#     367         return cls.from_datapackage(
#     368             data_package, load_species_data=load_species_data,
#
# /home/root/ipython/src/flotilla/flotilla/datapackage.pyc in data_package_url_to_dict(data_package_url)
#      10
#      11 def data_package_url_to_dict(data_package_url):
# ---> 12     filename = check_if_already_downloaded(data_package_url)
#      13
#      14     with open(filename) as f:
#
# /home/root/ipython/src/flotilla/flotilla/datapackage.pyc in check_if_already_downloaded(url, datapackage_name, download_dir)
#      42         req = urllib2.Request(url)
#      43         opener = urllib2.build_opener()
# ---> 44         opened_url = opener.open(req)
#      45         datapackage = json.loads(opened_url.read())
#      46         datapackage_name = datapackage['name']
#
# /usr/local/miniconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     394
#     395         req.timeout = timeout
# --> 396         protocol = req.get_type()
#     397
#     398         # pre-process request
#
# /usr/local/miniconda/lib/python2.7/urllib2.pyc in get_type(self)
#     256             self.type, self.__r_type = splittype(self.__original)
#     257             if self.type is None:
# --> 258                 raise ValueError, "unknown url type: %s" % self.__original
#     259         return self.type
#     260
#
# ValueError: unknown url type: neural_diff_demo

# %%
study.plot_pca()

# %% [markdown]
# <a name="check_gene"></a>
# ##Check for markers of specified lineages
# ###Use official gene symbols or Ensembl IDs to plot distribution of expression for a single gene.
# <br>
#   * POU5F1 (OCT4) - Stem cells
#
#   * NES (Nestin) - Neural Progenitors
#
#   * DCX (Doublecortin) - Neurons
#
#   * HSP90AB1 (Heat-shock protein 90 $\alpha$) - Stressed cells

# %%
study.plot_gene("POU5F1")

# %%
study.plot_gene("NES")

# %%
study.plot_gene("DCX")

# %%
study.plot_gene("HSP90AA1")

# %% [markdown]
# ##Interactive PCA
# ###Choose feature type, sample subset, and feature subsets to perform PCA.
# ###By default, the most variant features among the samples selected are used to perform PCA.

# %% [markdown]
# <a name="interact"></a>
# ###HTML widgets allow user interaction:
# <img src="img/interactive_pca_widgets.png" align='center'/>
#
# Alternatively (_for presentations like this for example_) users can set the range of options at the function call.

# %% [markdown]
# ####`interactive_pca` options:
#   <br>
#   * Select `data_type` (expression/splicing), `sample_subset`, `feature_subset` from pull-down menus.
#   <br>
#   <br>
#   * Transpose with _featurewise_ to examine relationships between features
#   <br>
#   <br>
#   * Use custom lists from the internet _(Dropbox?)_ or local file paths with `list_link` and the _custom_ feature subset.
#   <br>
#   <br>
#   * Choose other principal components to plot with sliders.
#   <br>
#   <br>
#   * Plot violin plots with `plot_violins`
#   <br>
#   <br>
#   * Label samples

# %% [markdown]
# ####sample_subsets include:
#
#   * All boolean columns in `study.metadata.data`
#
#   * Phenotypes
#
#   * Pooled samples
#
#   * Outliers

# %% [markdown]
# ####`feature_subset`s include:
#   * Everything annotated in Gencode
#
#      * Protein coding genes
#
#      * lncRNA
#
#      * snoRNA/snRNA/tRNA...
#
#      * Pseudogenes
#
#
#   * And some things that are not
#
#      * RNA-binding proteins
#
#      * Neural celltype lineage markers from (Fluidigm) biomark panel.
#
#      * Transcription factors

# %%
study.interactive_pca(show_point_labels=True);
# Out:
# savefile : data/last.pca.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : True
# sample_subset : all_samples
# feature_subset : variant
# plot_violins : False
# x_pc : 1
# list_link :

# %% [markdown]
# ###Sample P_P2_06 and N_N5_11 look like outliers. Let's remove them.

# %%
study.metadata.data.ix[['P_P2_06', 'N_N5_11'], 'outlier'] = True

# %%
study.drop_outliers()
# Out:
# dropping expression outliers
# dropping set(['P_P2_06', 'N_N5_11'])
# dropping splicing outliers
# dropping set(['P_P2_06', 'N_N5_11'])

# %%
study.interactive_pca();
# Out:
# savefile : data/last.pca.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : False
# sample_subset : all_samples
# feature_subset : variant
# plot_violins : False
# x_pc : 1
# list_link :

# %% [markdown]
# <a name="negation"></a>
# ###Use `'~'` to indicate the logical inverse of a column

# %%
study.interactive_pca(sample_subsets=["~P_cell"], 
                      feature_subsets=['gene_type: protein_coding']);
# Out:
# savefile : data/last.pca.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : False
# sample_subset : ~P_cell
# feature_subset : gene_type: protein_coding
# plot_violins : False
# x_pc : 1
# list_link :

# %% [markdown]
# <a name="modify_subsets"></a>
# ###Make new subsets to plot
# #### Get cells that are either P, S or pooled (i.e. only N and M single cells `== False`).

# %%
study.metadata.data['PS_pooled_cells'] = study.merge_boolean_metadata_columns(['P_cell', 
                                                                              'S_cell', 
                                                                              'pooled_samples'])

# %%
study.interactive_pca(sample_subsets=["~PS_pooled_cells"], 
                      feature_subsets=['gene_type: protein_coding']);
# Out:
# savefile : data/last.pca.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : False
# sample_subset : ~PS_pooled_cells
# feature_subset : gene_type: protein_coding
# plot_violins : False
# x_pc : 1
# list_link :

# %% [markdown]
# <a name="dropbox"></a>
# ###Check a gene list from a collaborator.

# %%
study.interactive_pca(sample_subsets=["~PS_pooled_cells"],
                      feature_subsets=['custom'],
                      list_link="https://www.dropbox.com/s/qddybszcses6pi6/DE_genes.male%20adult%20%2019.txt?dl=0")
# Out:
# savefile : data/last.pca.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : False
# sample_subset : ~PS_pooled_cells
# feature_subset : custom
# plot_violins : False
# x_pc : 1
# list_link : https://www.dropbox.com/s/qddybszcses6pi6/DE_genes.male%20adult%20%2019.txt?dl=0
# link https://www.dropbox.com/s/qddybszcses6pi6/DE_genes.male%20adult%20%2019.txt?dl=0
# WARNING, downloading things from the internet, potential danger from untrusted sources
# <function flotilla.visualize.ipython_interact.do_interact>

# %% [markdown]
# ###Keep all changes (_i.e. the new metadata column_) for the next embark.

# %%
study.save("neural_diff_demo")
# Out:
# Wrote datapackage to /Users/lovci/flotilla_projects/neural_diff_demo/datapackage.json

# %% [markdown]
# ##Summary
#
#   With minimal coding users can interact and visualize complex patterns in their data.
#
#   Users can:
#
#   * <a href="#check_gene">Examine expression of interesting genes among phenotypes</a>
#
#   * <a href="#interact">Modify parameters with interactive HTML widgets</a>
#
#   * <a href="#negation">Select the inverse of sample subsets.</a>
#
#   * <a href="#modify_subsets">Modify sample/feature subsets on the fly.</a>
#
#   * <a href="#dropbox">Use feature lists from web sources.</a>

# %% [markdown]
# ##Next steps
# <br>
# Now, continue to the [Classification/Feature Selection](3_Classification.ipynb) notebook.
