# %% [markdown]
# #In this notebook
#
# ###Represent proximity in high-dimensional space with a network graph

# %%
import css_styling
# Out:
# <link rel="stylesheet" href="http://bootswatch.com/paper/bootstrap.css">

# %%
import flotilla

# %%
study = flotilla.embark("neural_diff_demo")
# Out:
# 2014-11-01 19:17:27	Reading datapackage from /Users/lovci/flotilla_projects/neural_diff_demo/datapackage.json
# 2014-11-01 19:17:27	Parsing datapackage to create a Study object
# 2014-11-01 19:18:18	Initializing Study
# 2014-11-01 19:18:18	Initializing Predictor configuration manager for Study
# 2014-11-01 19:18:18	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2014-11-01 19:18:18	Added ExtraTreesClassifier to default predictors
# 2014-11-01 19:18:18	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2014-11-01 19:18:18	Added ExtraTreesRegressor to default predictors
# 2014-11-01 19:18:18	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2014-11-01 19:18:18	Added GradientBoostingClassifier to default predictors
# 2014-11-01 19:18:18	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2014-11-01 19:18:18	Added GradientBoostingRegressor to default predictors
# 2014-11-01 19:18:18	Loading metadata
# 2014-11-01 19:18:18	Loading species metadata from ~/flotilla_packages
# 2014-11-01 19:18:40	Loading expression data
# samples had too few mapped reads (<5.0e+05 reads):
# 	M_M2nd_23, M_M2nd_30, M_M2nd_31, M_M2nd_32, M_M3_10, P_P4_2, P_P8_12, P_P8_3, P_P8_4, P_P8_7, P_P8_8, P_P8_9, S_MSA_25
# Removing technical outliers from consideration in expression:
# 	M_M2nd_23, M_M2nd_30, M_M2nd_31, M_M2nd_32, M_M3_10, P_P4_2, P_P8_12, P_P8_3, P_P8_4, P_P8_7, P_P8_8, P_P8_9, S_MSA_25
# 2014-11-01 19:18:40	Initializing expression
# 2014-11-01 19:18:40	Done initializing expression
# 2014-11-01 19:18:41	Loading splicing data
# 2014-11-01 19:18:41	Initializing splicing
# 2014-11-01 19:18:42	Done initializing splicing
# 2014-11-01 19:18:42	Successfully initialized a Study object!
# Removing technical outliers from consideration in splicing:
# 	M_M2nd_23, M_M2nd_30, M_M2nd_31, M_M2nd_32, M_M3_10, P_P4_2, P_P8_12, P_P8_3, P_P8_4, P_P8_7, P_P8_8, P_P8_9, S_MSA_25

# %%
study.interactive_graph(weight_fun='arctan_sq', featurewise=True, feature_subsets=['confident_rbp'])
# Out:
# savefile : data/last.graph.pdf
# data_type : expression
# featurewise : True
# weight_fun : arctan_sq
# use_pc_4 : True
# use_pc_2 : True
# use_pc_3 : True
# sample_subset : all_samples
# use_pc_1 : True
# cov_std_cut : 1.8
# feature_subset : confident_rbp
# degree_cut : 1
# feature_of_interest : RBFOX2
# draw_labels : False
# n_pcs : 5
# <function flotilla.visualize.ipython_interact.do_interact>
