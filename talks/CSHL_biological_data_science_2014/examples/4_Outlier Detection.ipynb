# %%
import css_styling
# Out:
# <link rel="stylesheet" href="http://bootswatch.com/paper/bootstrap.css">

# %% [markdown]
# ##In this notebook:
# ###Choose and sample outliers with interactive functions.

# %% [markdown]
# The following functions are introduced:
#
#   * `study.interactive_choose_outliers`<br>
#     This function uses one-class SVM to identify outliers based on user-chosen fitting parameters.
#   <br>
#   <br>
#
#   * `study.interactive_reset_outliers`<br>
#     User can combine multiple outlier calls to set `study.metadata.data['outlier']`
#   <br>
#   <br>
#
#   * `study.drop_outliers`<br>
#     After setting the `outlier` attribute in `study.metadata.data` the samples labelled outliers are removed from `study.expression.data` and `study.splicing.data`

# %%
import flotilla

# %%
from time import time
a = time()

# %%
study = flotilla.embark("neural_diff_demo")
# Out:
# 2014-10-31 11:57:39	Reading datapackage from /Users/lovci/flotilla_projects/neural_diff_demo/datapackage.json
# 2014-10-31 11:57:39	Parsing datapackage to create a Study object
# 2014-10-31 11:58:28	Initializing Study
# 2014-10-31 11:58:28	Initializing Predictor configuration manager for Study
# 2014-10-31 11:58:28	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2014-10-31 11:58:28	Added ExtraTreesClassifier to default predictors
# 2014-10-31 11:58:28	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2014-10-31 11:58:28	Added ExtraTreesRegressor to default predictors
# 2014-10-31 11:58:28	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2014-10-31 11:58:28	Added GradientBoostingClassifier to default predictors
# 2014-10-31 11:58:28	Predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# 2014-10-31 11:58:28	Added GradientBoostingRegressor to default predictors
# 2014-10-31 11:58:28	Loading metadata
# 2014-10-31 11:58:28	Loading species metadata from ~/flotilla_packages
# 2014-10-31 11:58:49	Loading expression data
# 2014-10-31 11:58:49	Initializing expression
# 2014-10-31 11:58:49	Done initializing expression
# Removing technical outliers from consideration in expression:
# 	M_M2nd_23
# 	M_M2nd_30
# 	M_M2nd_31
# 	M_M2nd_32
# 	M_M3_10
# 	P_P4_2
# 	P_P8_12
# 	P_P8_3
# 	P_P8_4
# 	P_P8_7
# 	P_P8_8
# 	P_P8_9
# 	S_MSA_25
# Removing technical outliers from consideration in splicing:
# 	M_M2nd_23
# 	M_M2nd_30
# 	M_M2nd_31
# 	M_M2nd_32
# 	M_M3_10
# 	P_P4_2
# 	P_P8_12
# 	P_P8_3
# 	P_P8_4
# 	P_P8_7
# 	P_P8_8
# 	P_P8_9
# 	S_MSA_25
# 2014-10-31 11:58:50	Loading splicing data
# 2014-10-31 11:58:50	Initializing splicing
# 2014-10-31 11:58:51	Done initializing splicing
# 2014-10-31 11:58:51	Successfully initialized a Study object!

# %%
b = time()

print "This operation took {:.1f} seconds.".format(b - a)
# Out:
# This operation took 72.1 seconds.

# %%
study.interactive_pca();
# Out:
# savefile : data/last.pca.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : False
# sample_subset : all_samples
# feature_subset : variant
# plot_violins : False
# x_pc : 1
# list_link :

# %%
study.metadata.data['outlier_manual'] = False
study.metadata.data['outlier_manual'].ix[['S_MSA_19', 'M_M2nd_23', 'S_MSA_29']] = True

# %%
study.interactive_reset_outliers()
# Out:
# using thse columns:
#
#
# there are 0 outliers

# %%
study.drop_outliers()
# Out:
# dropping expression outliers
# dropping set([])
# dropping splicing outliers
# These cells are pooled, not outliers. Skipping...
#
# These cells are pooled, not outliers. Skipping...
# dropping set([])

# %%
study.interactive_choose_outliers()
# Out:
# transforming input gamma by 2^-(input): 16.000000
# transforming input nu by input/10: 0.200000
# y_pc : 2
# data_type : expression
# show_point_labels : False
# sample_subset : all_samples
# feature_subset : variant
# x_pc : 1
# nu : 0.02
# gamma : 1.52587890625e-05
# setting outlier type:
# outlier_expression_all_samples_variant
# in metadata
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/ipython_interact.pyc in do_interact(data_type, sample_subset, feature_subset, x_pc, y_pc, show_point_labels, gamma, nu)
#     532                               show_point_labels=show_point_labels,
#     533                               x_pc="pc_" + str(x_pc),
# --> 534                               y_pc="pc_" + str(y_pc))
#     535
#     536             print "total samples:", len(outlier_detector.outliers)
#
# /Users/lovci/Projects/flotilla_dev/flotilla/data_model/base.pyc in plot_outliers(self, reducer, outlier_detector, show_point_labels, feature_renamer, x_pc, y_pc)
#     669                               scale_by_variance=True, x_pc=x_pc,
#     670                               y_pc=y_pc, n_vectors=0, distance='L1',
# --> 671                               n_top_pc_features=50)
#     672
#     673         dv(show_point_labels=show_point_labels, title=outlier_detector.title)
#
# TypeError: __init__() got an unexpected keyword argument 'color'
# <function flotilla.visualize.ipython_interact.do_interact>

# %%
study.metadata.data['outlier_expression_all_samples_variant'].sum()

# %%
study.drop_outliers()

# %%
study.interactive_reset_outliers()

# %%
study.interactive_choose_outliers(sample_subsets=["M_cell"])

# %%
study.interactive_choose_outliers(sample_subsets=["N_cell"])

# %%
study.interactive_choose_outliers(sample_subsets=["P_cell"])

# %%
study.interactive_choose_outliers(sample_subsets=["S_cell"])

# %%
# !open data

# %%
study.interactive_reset_outliers()

# %%
study.drop_outliers()

# %%
study.interactive_choose_outliers()

# %%
interactive_reset_outliers(study)

# %%
study.drop_outliers()

# %%
study.interactive_pca()
