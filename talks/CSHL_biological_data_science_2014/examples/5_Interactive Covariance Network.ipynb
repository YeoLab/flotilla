# %% [markdown]
# #In this notebook
#
# ###Represent proximity in high-dimensional space with a network graph

# %%
import css_styling
# Out:
# <link rel="stylesheet" href="http://bootswatch.com/paper/bootstrap.css">

# %%
import flotilla

# %%
study = flotilla.embark("neural_diff_demo")
# Out:
# 2014-11-01 12:13:20	Reading datapackage from /Users/lovci/flotilla_projects/neural_diff_demo/datapackage.json
# 2014-11-01 12:13:20	Parsing datapackage to create a Study object
# 2014-11-01 12:14:11	Initializing Study
# 2014-11-01 12:14:11	Initializing Predictor configuration manager for Study
# 2014-11-01 12:14:11	Predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# 2014-11-01 12:14:11	Added ExtraTreesClassifier to default predictors
# 2014-11-01 12:14:11	Predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# 2014-11-01 12:14:11	Added ExtraTreesRegressor to default predictors
# 2014-11-01 12:14:11	Predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# 2014-11-01 12:14:11	Added GradientBoostingClassifier to default predictors
# ...

# %%
study.interactive_graph(weight_fun='arctan_sq', featurewise=True, feature_subsets=['confident_rbp'])
# Out:
# savefile : data/last.graph.pdf
# data_type : expression
# featurewise : True
# weight_fun : arctan_sq
# use_pc_4 : True
# use_pc_2 : True
# use_pc_3 : True
# sample_subset : all_samples
# use_pc_1 : True
# cov_std_cut : 1.8
# feature_subset : confident_rbp
# degree_cut : 1
# feature_of_interest : RBFOX2
# draw_labels : False
# n_pcs : 5
# <function flotilla.visualize.ipython_interact.do_interact>
