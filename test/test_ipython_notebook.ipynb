# %%
import flotilla
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
sns.set_context('talk')

# %%
study = flotilla.embark('http://sauron.ucsd.edu/flotilla_projects/neural_diff_chr22/datapackage.json')
# Out:
# initializing study
# predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# added ExtraTreesClassifier to default predictors
# predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# added ExtraTreesRegressor to default predictors
# predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# added GradientBoostingClassifier to default predictors
# predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# added GradientBoostingRegressor to default predictors
# loading expression data
# initializing expression
# done initializing expression
# loading splicing data
# dropping set(['M_M3_1', 'M_M3_11', 'M_M2_07', 'M_M1_03', 'M_M6_1', 'M_M2_02', 'M_M2_01', 'P_P2_06', 'S_MSA_23', 'M_M1_04', 'M_M2nd_23', 'M_M4_2', 'S_MSA_21', 'S_MSA_05', 'M_M4_13', 'M_M4_10', 'S_MSA_28', 'M_M6_2', 'M_M2_06', 'M_M3_3'])
# dropping set(['M_M3_1', 'M_M3_11', 'M_M2_07', 'M_M1_03', 'M_M6_1', 'M_M2_02', 'M_M2_01', 'P_P2_06', 'S_MSA_23', 'M_M1_04', 'M_M2nd_23', 'M_M4_2', 'S_MSA_21', 'S_MSA_05', 'M_M4_13', 'M_M4_10', 'S_MSA_28', 'M_M6_2', 'M_M2_06', 'M_M3_3'])
# initializing splicing
# done initializing splicing
# initializing expression
# done initializing expression
# subclasses initialized
# package validated

# %%
study = flotilla.embark('neural_diff_chr22')
# Out:
# initializing study
# predictor ExtraTreesClassifier is of type <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>
# added ExtraTreesClassifier to default predictors
# predictor ExtraTreesRegressor is of type <class 'sklearn.ensemble.forest.ExtraTreesRegressor'>
# added ExtraTreesRegressor to default predictors
# predictor GradientBoostingClassifier is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'>
# added GradientBoostingClassifier to default predictors
# predictor GradientBoostingRegressor is of type <class 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor'>
# added GradientBoostingRegressor to default predictors
# loading expression data
# initializing expression
# done initializing expression
# dropping set(['M_M3_11', 'M_M2_07', 'M_M1_03', 'M_M6_1', 'M_M2_02', 'M_M2_01', 'P_P2_06', 'S_MSA_23', 'M_M1_04', 'M_M3_1', 'M_M4_2', 'S_MSA_21', 'S_MSA_05', 'M_M4_13', 'M_M4_10', 'S_MSA_28', 'M_M6_2', 'M_M2_06', 'M_M3_3'])
# dropping set(['M_M3_11', 'M_M2_07', 'M_M1_03', 'M_M6_1', 'M_M2_02', 'M_M2_01', 'P_P2_06', 'S_MSA_23', 'M_M1_04', 'M_M3_1', 'M_M4_2', 'S_MSA_21', 'S_MSA_05', 'M_M4_13', 'M_M4_10', 'S_MSA_28', 'M_M6_2', 'M_M2_06', 'M_M3_3'])
# loading splicing data
# initializing splicing
# done initializing splicing
# initializing expression
# done initializing expression
# subclasses initialized
# package validated

# %%
study.interactive_pca(sample_subsets=['all_samples'], 
                      feature_subsets=['protein_coding'], 
                      savefile='figure1_a.pdf')
# Out:
# savefile : figure1_a.pdf
# y_pc : 2
# data_type : expression
# featurewise : False
# show_point_labels : False
# sample_subset : all_samples
# feature_subset : protein_coding
# x_pc : 1
# list_link :

# %%
study.interactive_pca(sample_subsets=['all_samples'], 
                      feature_subsets=['protein_coding'], 
                      savefile='figure1_b.pdf', featurewise=True)
# Out:
# savefile : figure1_b.pdf
# y_pc : 2
# data_type : expression
# featurewise : True
# show_point_labels : False
# sample_subset : all_samples
# feature_subset : protein_coding
# x_pc : 1
# list_link :
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/ipython_interact.py in do_interact(data_type, sample_subset, feature_subset, featurewise, list_link, x_pc, y_pc, show_point_labels, savefile)
#     129                                 x_pc=x_pc, y_pc=y_pc,
#     130                                 show_point_labels=show_point_labels,
# --> 131                                 feature_subset=feature_subset)
#     132             if savefile != '':
#     133                 # Make the directory if it's not already there
#
# /Users/lovci/Projects/flotilla_dev/flotilla/data_model/study.py in plot_pca(self, data_type, x_pc, y_pc, sample_subset, feature_subset, title, featurewise, show_point_labels, reduce_kwargs, **kwargs)
#     777                 order=order, color=color,
#     778                 featurewise=featurewise, show_point_labels=show_point_labels,
# --> 779                 title=title, reduce_kwargs=reduce_kwargs, **kwargs)
#     780         elif "splicing".startswith(data_type):
#     781             reducer = self.splicing.plot_pca(
#
# /Users/lovci/Projects/flotilla_dev/flotilla/data_model/base.py in plot_pca(self, **kwargs)
#     368     def plot_pca(self, **kwargs):
#     369         return self.plot_dimensionality_reduction(reducer=DataFramePCA,
# --> 370                                                   **kwargs)
#     371
#     372     @property
#
# /Users/lovci/Projects/flotilla_dev/flotilla/data_model/base.py in plot_dimensionality_reduction(self, x_pc, y_pc, sample_ids, feature_ids, featurewise, reducer, label_to_color, label_to_marker, groupby, order, color, reduce_kwargs, title, **plotting_kwargs)
#     364         # pca(show_vectors=True,
#     365         #     **plotting_kwargs)
# --> 366         return visualized(title=title, **plotting_kwargs)
#     367
#     368     def plot_pca(self, **kwargs):
#
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/decomposition.py in __call__(self, ax, title, show_point_labels, show_vectors, show_vector_labels, markersize, legend)
#     148
#     149         if self.DataModel is not None:
# --> 150             self.plot_violins()
#     151         return self
#     152
#
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/decomposition.py in plot_violins(self)
#     340                                        phenotype_groupby=self.groupby,
#     341                                        phenotype_order=self.order,
# --> 342                                        ax=ax, color=self.color)
#     343
#     344         # Clear any unused axes
#
# /Users/lovci/Projects/flotilla_dev/flotilla/data_model/base.py in _violinplot(self, feature_id, sample_ids, phenotype_groupby, phenotype_order, ax, color, label_pooled)
#     693                    pooled_data=pooled, order=phenotype_order,
#     694                    title=title, data_type=self.data_type, ax=ax,
# --> 695                    label_pooled=label_pooled, outliers=outliers)
#     696
#     697     @cached_property()
#
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/generic.py in violinplot(data, groupby, color, ax, pooled_data, order, violinplot_kws, title, label_pooled, outliers, data_type)
#      45                     pass
#      46         else:
# ---> 47             plot_pooled_dot(ax, pooled_data)
#      48
#      49     if outliers is not None:
#
# /Users/lovci/Projects/flotilla_dev/flotilla/visualize/generic.py in plot_pooled_dot(ax, pooled, x_offset, label)
#     162         xs = np.zeros(1)
#     163     xs += x_offset
# --> 164     ax.plot(xs, pooled, 'o', color='#262626')
#     165
#     166     if label:
#
# /Users/lovci/venv/lib/python2.7/site-packages/matplotlib-1.3.1-py2.7-macosx-10.6-intel.egg/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /Users/lovci/venv/lib/python2.7/site-packages/matplotlib-1.3.1-py2.7-macosx-10.6-intel.egg/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     315                 return
#     316             if len(remaining) <= 3:
# --> 317                 for seg in self._plot_args(remaining, kwargs):
#     318                     yield seg
#     319                 return
#
# /Users/lovci/venv/lib/python2.7/site-packages/matplotlib-1.3.1-py2.7-macosx-10.6-intel.egg/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     303         ncx, ncy = x.shape[1], y.shape[1]
#     304         for j in xrange(max(ncx, ncy)):
# --> 305             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     306             ret.append(seg)
#     307         return ret
#
# ZeroDivisionError: integer division or modulo by zero

# %%
study.interactive_graph(feature_subsets=['protein_coding'], 
                        savefile='figure2_a.pdf')
# Out:
# savefile : figure2_a.pdf
# data_type : expression
# featurewise : True
# weight_fun : no_weight
# use_pc_4 : True
# use_pc_2 : True
# use_pc_3 : True
# sample_subset : all_samples
# use_pc_1 : True
# cov_std_cut : 1.8
# feature_subset : protein_coding
# degree_cut : 1
# feature_of_interest : RBFOX2
# draw_labels : False
# n_pcs : 5
# u'RBFOX2'

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
study.interactive_classifier(feature_subsets=['protein_coding'], 
                             savefile='figure2_a.pdf')
# Out:
# savefile : figure2_a.pdf
# predictor_type : ExtraTreesClassifier
# data_type : expression
# score_coefficient : 2.0
# sample_subset : all_samples
# feature_subset : protein_coding
# categorical_variable : M_cell
# Fitting a predictor for X:all_samples_protein_coding, y:M_cell, method:ExtraTreesClassifier... please wait.
# configuring predictor type: ExtraTreesClassifier with 384 features[Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# 	Finished.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
